# %% [markdown]
# ## Pandas
# - Pandas es una biblioteca de programacion de Python que proporcina estructura de datos y herramientas de analisis de datos.
# - DataFrame que es una tabla bidimimensioal con etiquetas filas y columnas.
# ![Pandas](pandas.png)

# %%
import pandas as pd
pd.read_csv

# %%
data = {
         'Nombre':['Juan','Armando','Luis'],
         'Edad':[25,30,22],
         'Ciudad':['Bogota','Cali','Medellin'] 
       }

# %%
data
# Out:
# {'Nombre': ['Juan', 'Armando', 'Luis'],
#  'Edad': [25, 30, 22],
#  'Ciudad': ['Bogota', 'Cali', 'Medellin']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     Nombre  Edad    Ciudad
# 0     Juan    25    Bogota
# 1  Armando    30      Cali
# 2     Luis    22  Medellin

# %%
df.head()
# Out:
#     Nombre  Edad    Ciudad
# 0     Juan    25    Bogota
# 1  Armando    30      Cali
# 2     Luis    22  Medellin

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nombre  3 non-null      object
#  1   Edad    3 non-null      int64
#  2   Ciudad  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
#Filtrar datos
df_mayor_25=df[df['Edad']>25]
df_mayor_25
# Out:
#     Nombre  Edad Ciudad
# 1  Armando    30   Cali

# %%
df['Profesion'] =['Ingeniero','Doctor','Estudiante']
df
# Out:
#     Nombre  Edad    Ciudad   Profesion
# 0     Juan    25    Bogota   Ingeniero
# 1  Armando    30      Cali      Doctor
# 2     Luis    22  Medellin  Estudiante

# %%
df_data=pd.read_csv('data.csv')
df_data
# Out:
#    codigo nombre  edad
# 0       1   jose    23
# 1       2   luis    22
# 2       3  pedro    17

# %%
df_vic=pd.read_csv('denuncias-victimas-pgj.csv')
df_vic.head()
# Out:
#    id  idcarpeta                                             delito  \
# 0   0    8511202                                 VIOLENCIA FAMILIAR
# 1   1    8511203                                 VIOLENCIA FAMILIAR
# 2   2    8511210                       NARCOMENUDEO POSESION SIMPLE
# 3   3    8511220        ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO
# 4   4    8511227  ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI...
#
#                               categoria           fechahecho      ao  \
# 0                DELITO DE BAJO IMPACTO  2019-08-31 20:30:00  2019.0
# 1                DELITO DE BAJO IMPACTO  2019-08-31 17:00:00  2019.0
# 2                DELITO DE BAJO IMPACTO  2019-08-31 23:30:00  2019.0
# 3                DELITO DE BAJO IMPACTO  2019-09-01 00:00:00  2019.0
# 4  ROBO DE VEHÍCULO CON Y SIN VIOLENCIA  2019-09-01 01:50:00  2019.0
#
#           mes      sexo  edad tipopersona        calidadjuridica  \
# 0      Agosto  Femenino  24.0      FISICA  VICTIMA Y DENUNCIANTE
# ...

# %%
df_vic.describe()
# Out:
#                   id     idcarpeta             ao           edad  \
# count  145870.000000  1.458700e+05  145743.000000  100547.000000
# mean    72934.500000  8.425766e+06    2018.865222      38.681413
# std     42109.186221  6.090228e+04       0.898186      16.410693
# min         0.000000  8.322418e+06    1964.000000       0.000000
# 25%     36467.250000  8.373664e+06    2019.000000      27.000000
# 50%     72934.500000  8.423324e+06    2019.000000      37.000000
# 75%    109401.750000  8.478405e+06    2019.000000      49.000000
# max    145869.000000  9.006473e+06    2019.000000     258.000000
#
#                  lon            lat
# count  140143.000000  140143.000000
# mean      -99.136049      19.387313
# std         0.060952       0.068799
# min       -99.340718      19.130325
# 25%       -99.176119      19.341308
# 50%       -99.140794      19.388654
# 75%       -99.097270      19.437284
# max       -98.948126      19.582323

# %%
df_vic.tail()
# Out:
#             id  idcarpeta                       delito  \
# 145865  145865    8533929                 ABUSO SEXUAL
# 145866  145866    8533931           VIOLENCIA FAMILIAR
# 145867  145867    8533933                      DESPOJO
# 145868  145868    8533947  HOMICIDIO POR ARMA DE FUEGO
# 145869  145869    8533948           ABUSO DE AUTORIDAD
#
#                      categoria           fechahecho      ao         mes  \
# 145865  DELITO DE BAJO IMPACTO  2019-09-28 20:00:00  2019.0  Septiembre
# 145866  DELITO DE BAJO IMPACTO  2019-09-30 20:00:00  2019.0  Septiembre
# 145867  DELITO DE BAJO IMPACTO  2019-08-29 14:00:00  2019.0      Agosto
# 145868        HOMICIDIO DOLOSO  2019-09-30 23:49:00  2019.0  Septiembre
# 145869  DELITO DE BAJO IMPACTO  2019-09-30 20:45:00  2019.0  Septiembre
#
#              sexo  edad tipopersona        calidadjuridica  \
# 145865   Femenino  22.0      FISICA  VICTIMA Y DENUNCIANTE
# 145866   Femenino  20.0      FISICA  VICTIMA Y DENUNCIANTE
# ...

# %%
df_vic.loc[2]
# Out:
# id                                                2
# idcarpeta                                   8511210
# delito                 NARCOMENUDEO POSESION SIMPLE
# categoria                    DELITO DE BAJO IMPACTO
# fechahecho                      2019-08-31 23:30:00
# ao                                           2019.0
# mes                                          Agosto
# sexo                                            NaN
# edad                                            NaN
# tipopersona                                   MORAL
# calidadjuridica                             VICTIMA
# clasificaciondelito                     FUERO COMUN
# lon                                      -99.041738
# lat                                       19.379067
# geopoint               19.3790668024,-99.0417384999
# Name: 2, dtype: object

# %%
df_vic.loc[[2,3,6,7,8]]
# Out:
#    id  idcarpeta                                       delito  \
# 2   2    8511210                 NARCOMENUDEO POSESION SIMPLE
# 3   3    8511220  ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO
# 6   6    8511229                   ROBO DE ACCESORIOS DE AUTO
# 7   7    8511238                  POSESION DE VEHICULO ROBADO
# 8   8    8511239                                    VIOLACION
#
#                 categoria           fechahecho      ao         mes      sexo  \
# 2  DELITO DE BAJO IMPACTO  2019-08-31 23:30:00  2019.0      Agosto       NaN
# 3  DELITO DE BAJO IMPACTO  2019-09-01 00:00:00  2019.0  Septiembre  Femenino
# 6  DELITO DE BAJO IMPACTO  2019-09-01 00:45:00  2019.0  Septiembre  Femenino
# 7  DELITO DE BAJO IMPACTO  2019-09-01 00:35:00  2019.0  Septiembre       NaN
# 8               VIOLACIÓN  2019-08-31 13:08:00  2019.0      Agosto  Femenino
#
#    edad tipopersona        calidadjuridica clasificaciondelito        lon  \
# ...

# %%
#df_vic[['categoria','sexo','tipopersona']]
df_vic.loc[[2,3,6,7,8],['categoria','sexo','tipopersona']]
# Out:
#                 categoria      sexo tipopersona
# 2  DELITO DE BAJO IMPACTO       NaN       MORAL
# 3  DELITO DE BAJO IMPACTO  Femenino      FISICA
# 6  DELITO DE BAJO IMPACTO  Femenino      FISICA
# 7  DELITO DE BAJO IMPACTO       NaN       MORAL
# 8               VIOLACIÓN  Femenino      FISICA

# %%
df_vic['categoria'].unique()
# Out:
# array(['DELITO DE BAJO IMPACTO', 'ROBO DE VEHÍCULO CON Y SIN VIOLENCIA',
#        'VIOLACIÓN', 'HECHO NO DELICTIVO', 'HOMICIDIO DOLOSO',
#        'LESIONES DOLOSAS POR DISPARO DE ARMA DE FUEGO',
#        'ROBO A TRANSEUNTE EN VÍA PÚBLICA CON Y SIN VIOLENCIA',
#        'ROBO A PASAJERO A BORDO DEL METRO CON Y SIN VIOLENCIA',
#        'ROBO A PASAJERO A BORDO DE MICROBUS CON Y SIN VIOLENCIA',
#        'ROBO A REPARTIDOR CON Y SIN VIOLENCIA',
#        'ROBO A TRANSPORTISTA CON Y SIN VIOLENCIA',
#        'ROBO A CASA HABITACIÓN CON VIOLENCIA',
#        'ROBO A CUENTAHABIENTE SALIENDO DEL CAJERO CON VIOLENCIA',
#        'ROBO A NEGOCIO CON VIOLENCIA',
#        'ROBO A PASAJERO A BORDO DE TAXI CON VIOLENCIA', 'SECUESTRO'],
#       dtype=object)

# %%
df_vic.loc[df_vic['categoria']=='ROBO A REPARTIDOR CON Y SIN VIOLENCIA'].head(20)
# Out:
#         id  idcarpeta                           delito  \
# 140    140    8511805  ROBO A REPARTIDOR CON VIOLENCIA
# 159    159    8511912  ROBO A REPARTIDOR CON VIOLENCIA
# 161    161    8511928  ROBO A REPARTIDOR CON VIOLENCIA
# 316    316    8512691  ROBO A REPARTIDOR CON VIOLENCIA
# 376    376    8512953  ROBO A REPARTIDOR CON VIOLENCIA
# 413    413    8513113  ROBO A REPARTIDOR CON VIOLENCIA
# 417    417    8513127  ROBO A REPARTIDOR CON VIOLENCIA
# 811    811    8515113  ROBO A REPARTIDOR CON VIOLENCIA
# 962    962    8515771  ROBO A REPARTIDOR CON VIOLENCIA
# 1095  1095    8516325  ROBO A REPARTIDOR CON VIOLENCIA
# 1096  1096    8516325  ROBO A REPARTIDOR CON VIOLENCIA
# 1134  1134    8516447  ROBO A REPARTIDOR CON VIOLENCIA
# 1171  1171    8516571  ROBO A REPARTIDOR CON VIOLENCIA
# 1187  1187    8516631  ROBO A REPARTIDOR SIN VIOLENCIA
# 1380  1380    8517479  ROBO A REPARTIDOR CON VIOLENCIA
# 1444  1444    8517735  ROBO A REPARTIDOR CON VIOLENCIA
# ...
